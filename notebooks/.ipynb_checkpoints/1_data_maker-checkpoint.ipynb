# %%
import pandas as pd
import os
from PIL import Image
import numpy as np

# %%
# Load the metadata CSV file
metadata = pd.read_csv('G:/My Drive/new/data/HAM10000_metadata.csv')

# %%
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# Define the path to the image directories
image_dir_1 = 'G:/My Drive/new/data/HAM10000_images_part_1'
image_dir_2 = 'G:/My Drive/new/data/HAM10000_images_part_2'

# You can merge the two directories if they are separate
all_image_paths = [os.path.join(image_dir_1, fname) for fname in os.listdir(image_dir_1)] + \
                  [os.path.join(image_dir_2, fname) for fname in os.listdir(image_dir_2)]

# %%
# Create a dictionary to map image IDs to their file paths
image_path_dict = {os.path.splitext(os.path.basename(path))[0]: path for path in all_image_paths}

# Add a new column to the metadata DataFrame with the image paths
metadata['image_path'] = metadata['image_id'].map(image_path_dict)

# Display the first few rows to ensure everything is correct
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                               image_path
# 0      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 1      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 2      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 3      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 4      G:/My Drive/new/data/HAM10000_images_part_2\IS...
# ...                                                  ...
# 10010  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10011  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10012  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10013  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10014  G:/My Drive/new/data/HAM10000_images_part_2\IS...
#
# [10015 rows x 8 columns]

# %%
# Check for missing image files
missing_files = metadata[metadata['image_path'].isnull()]

if len(missing_files) > 0:
    print(f"Missing files for {len(missing_files)} records.")

# %%
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                               image_path
# 0      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 1      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 2      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 3      G:/My Drive/new/data/HAM10000_images_part_1\IS...
# 4      G:/My Drive/new/data/HAM10000_images_part_2\IS...
# ...                                                  ...
# 10010  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10011  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10012  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10013  G:/My Drive/new/data/HAM10000_images_part_2\IS...
# 10014  G:/My Drive/new/data/HAM10000_images_part_2\IS...
#
# [10015 rows x 8 columns]

# %%
metadata.to_csv('G:/My Drive/new/data/test_data.csv', index=False)

# %%
def process_image(image_path):
    # Load the image
    img = Image.open(image_path)
    
    # Resize the image to 28x28
    img = img.resize((28, 28))
    
    # Convert the image to a numpy array
    img_array = np.array(img)
    
    # Flatten the image array into a 1D array of shape (2352,)
    # First 784 values for Red, next 784 for Green, and last 784 for Blue
    r = img_array[:, :, 0].flatten()  # Red channel
    g = img_array[:, :, 1].flatten()  # Green channel
    b = img_array[:, :, 2].flatten()  # Blue channel
    
    # Concatenate the three channels into a single 1D array
    flat_image = np.concatenate([r, g, b])
    
    return flat_image

# %%
image_data = []

# %%
for image_path in metadata['image_path']:
    flat_image = process_image(image_path)
    image_data.append(flat_image)

# %%
image_df = pd.DataFrame(image_data)

# %%
image_df.columns = [f'r_{i}' for i in range(784)] + [f'g_{i}' for i in range(784)] + [f'b_{i}' for i in range(784)]

# %%
metadata.drop(columns=['image_path', 'dx_type', 'lesion_id', 'image_id'], inplace=True)

# %%
metadata_with_images = pd.concat([metadata, image_df], axis=1)

# %%
metadata_with_images.head()
# Out:
#     dx   age   sex localization  r_0  r_1  r_2  r_3  r_4  r_5  ...  b_774  \
# 0  bkl  80.0  male        scalp  192  195  197  202  208  209  ...    185
# 1  bkl  80.0  male        scalp   27   69  122  158  172  175  ...    188
# 2  bkl  80.0  male        scalp  192  200  202  206  207  209  ...    157
# 3  bkl  80.0  male        scalp   40   95  143  171  178  190  ...    145
# 4  bkl  75.0  male          ear  159  194  215  225  232  235  ...    216
#
#    b_775  b_776  b_777  b_778  b_779  b_780  b_781  b_782  b_783
# 0    193    198    193    183    151    135    139    165    177
# 1    173    191    180    141     99     81     54     29     26
# 2    155    175    154    172    175    150    144    141    118
# 3    123    137    147    147    115     74     37     17     15
# 4    217    201    175    206    206    202    185    148     94
#
# [5 rows x 2356 columns]

# %%
import matplotlib.pyplot as plt

# Assume 'metadata_with_images' is your DataFrame with 2352 RGB columns
# Select a subset of data for plotting (e.g., first 5 images)
subset = metadata_with_images.head(10)

# Extract RGB columns
rgb_columns = [f'r_{i}' for i in range(784)] + [f'g_{i}' for i in range(784)] + [f'b_{i}' for i in range(784)]

# Loop through the subset and plot each image with its features
for index, row in subset.iterrows():
    # Extract RGB values
    r = row[[f'r_{i}' for i in range(784)]].values.reshape(28, 28)
    g = row[[f'g_{i}' for i in range(784)]].values.reshape(28, 28)
    b = row[[f'b_{i}' for i in range(784)]].values.reshape(28, 28)
    
    # Stack the channels to get the original image shape (28x28x3)
    img = np.stack([r, g, b], axis=-1)
    
    # Plot the image
    plt.figure(figsize=(10, 5))
    
    # Display the image
    plt.subplot(1, 2, 1)
    plt.imshow(img.astype(np.uint8))
    plt.title(f"Image {index + 1}")
    plt.axis('off')
    
    # Display some features (e.g., first few metadata columns)
    plt.subplot(1, 2, 2)
    feature_text = '\n'.join([f'{col}: {row[col]}' for col in metadata.columns[:5]])  # Display first 5 features
    plt.text(0.1, 0.5, feature_text, fontsize=12)
    plt.axis('off')
    
    plt.show()

# %%
metadata_with_images
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 metadata_with_images
#
# NameError: name 'metadata_with_images' is not defined

# %%
metadata_with_images.to_csv('metadata_with_images.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 metadata_with_images.to_csv('metadata_with_images.csv', index=False)
#
# NameError: name 'metadata_with_images' is not defined
